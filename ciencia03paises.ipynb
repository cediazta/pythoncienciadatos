# %%
import pandas as pd

# %% [markdown]
# Creamos un diccionario con paises.

# %%
dataPaises = {
    "pais": ["España", "Francia", "Colombia", "Mexico", "Peru"], 
    "capital": ["Madrid", "Paris", "Bogota", "Ciudad de Mexico", "Lima"],
    "superficie": [1.9, 2.5, 3.9, 4.0, 2.8],
}

# %% [markdown]
# Creamos un DataFrame con el diccionario.

# %%
df = pd.DataFrame(dataPaises)
df
# Out:
#        pais           capital  superficie
# 0    España            Madrid         1.9
# 1   Francia             Paris         2.5
# 2  Colombia            Bogota         3.9
# 3    Mexico  Ciudad de Mexico         4.0
# 4      Peru              Lima         2.8

# %% [markdown]
# Por ejemplo, podemos dibujar solamente una columna

# %%
df[['capital']]
# Out:
#             capital
# 0            Madrid
# 1             Paris
# 2            Bogota
# 3  Ciudad de Mexico
# 4              Lima

# %% [markdown]
# podemos dibujar mas de una columna

# %%
df[['capital', 'superficie']]
# Out:
#             capital  superficie
# 0            Madrid         1.9
# 1             Paris         2.5
# 2            Bogota         3.9
# 3  Ciudad de Mexico         4.0
# 4              Lima         2.8

# %% [markdown]
# Se pueden seleccionar filas por su disposicion del indice.
# Primero incluido y el segundo no incluido.

# %%
df[2:5]
# Out:
#        pais           capital  superficie
# 2  Colombia            Bogota         3.9
# 3    Mexico  Ciudad de Mexico         4.0
# 4      Peru              Lima         2.8

# %% [markdown]
# Por defecto, los indices de los elementos son numericos y los pone automaticamente.
# Podemos crear nuestros propios indices y sustituir el index.

# %%
df.index = ["ES", "FR", "CO", "MX", "PE"]
df.reset_index()
# Out:
#   index      pais           capital  superficie
# 0    ES    España            Madrid         1.9
# 1    FR   Francia             Paris         2.5
# 2    CO  Colombia            Bogota         3.9
# 3    MX    Mexico  Ciudad de Mexico         4.0
# 4    PE      Peru              Lima         2.8
